# %%
N=256
import numpy as np
from scipy.ndimage import gaussian_filter
nd=np.load("/data/dell5/userdir/heyi/EAGLE/5.21_gu_256.npy")

#空网格加上平均数密度
ave=np.sum(nd)/N/N/N
nd=(nd-ave)/ave

deltk=np.fft.fftn(nd) #傅里叶转换

s=1.5*0.272*0.704**2*10**4
v=2*np.pi/300            #2*pi/L L为bo'x
a=np.fft.fftfreq(N,1./N)

nx=a[:,None,None]+np.zeros_like(a[None,:,None])+np.zeros_like(a[None,None,:])
ny=a[None,:,None]+np.zeros_like(a[:,None,None])+np.zeros_like(a[None,None,:])
nz=a[None,None,:]+np.zeros_like(a[:,None,None])+np.zeros_like(a[None,:,None])

deltk=deltk/(np.sinc(nx/N)*np.sinc(ny/N)*np.sinc(nz/N))**2

k=np.sqrt((v*nx)**2+(v*ny)**2+(v*nz)**2)

Rs=2.1              #smooth scale
deltk=deltk*np.exp(-0.5*k*k*Rs**2)

fik=s*deltk/(-k**2)

#fik=fik*np.exp(-0.5*k*k*100)#直接求T 二阶偏导
fik[0,0,0]=0.0

h11=-fik*v*nx*v*nx
h12=h21=-fik*v*nx*v*ny
h13=h31=-fik*v*nx*v*nz
h22=-fik*v*ny*v*ny
h23=h32=-fik*v*ny*v*nz
h33=-fik*v*nz*v*nz

h11=np.fft.ifftn(h11)
h12=h21=np.fft.ifftn(h12)
h13=h31=np.fft.ifftn(h13)
h22=np.fft.ifftn(h22)
h23=h32=np.fft.ifftn(h23)
h33=np.fft.ifftn(h33)

h11=h11.reshape(N**3,1).real
h12=h21=h12.reshape(N**3,1).real
h13=h31=h13.reshape(N**3,1).real
h22=h22.reshape(N**3,1).real
h23=h32=h23.reshape(N**3,1).real
h33=h33.reshape(N**3,1).real


ten=np.hstack((h11,h12,h13,h21,h22,h23,h31,h32,h33)).reshape(-1,3,3)
ten=np.array(ten,dtype=np.float32)
lm,l=np.linalg.eig(ten)
lmdn=np.ones((N**3,12),dtype=np.float32)
lmdn[:,0]=lm[:,0]
lmdn[:,1:4]=l[:,:,0]
lmdn[:,4]=lm[:,1]
lmdn[:,5:8]=l[:,:,1]
lmdn[:,8]=lm[:,2]
lmdn[:,9:12]=l[:,:,2]
# Out:
# /home/guestupload/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:27: RuntimeWarning: divide by zero encountered in true_divide
# /home/guestupload/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:27: RuntimeWarning: invalid value encountered in true_divide

# %%
Rth=0.4#threshold
import numpy as np
eig=lmdn

s=1.5*0.272*0.704**2*10**4
#s=1.5*0.307*0.6777**2*10**4
eig=lmdn
eig[:,0]=eig[:,0]/s
eig[:,4]=eig[:,4]/s
eig[:,8]=eig[:,8]/s

print (1)
lmd=np.zeros((N**3,3),dtype=np.float)
n1=np.zeros((N**3,3),dtype=np.float)
n2=np.zeros((N**3,3),dtype=np.float)
n3=np.zeros((N**3,3),dtype=np.float)

lmd[:,0]=eig[:,0]
lmd[:,1]=eig[:,4]
lmd[:,2]=eig[:,8]

print(2) 
n1[:,0:3]=eig[:,1:4]
n2[:,0:3]=eig[:,5:8]
n3[:,0:3]=eig[:,9:12]
print(3)

a=lmd>Rth

print(4)
b=a[:,0]*2**2+a[:,1]*2+a[:,2]*1
c=(b==7)*3
f=((b==6)|(b==5)|(b==3))*2
s=((b==4)|(b==2)|(b==1))*1
v=(b==0)*0

fil=c+f+s+v
print(5)
filn1=(b==6).reshape(-1,1)*n3
filn2=(b==5).reshape(-1,1)*n2
filn3=(b==3).reshape(-1,1)*n1
filn=filn1[:,0:3]+filn2[:,0:3]+filn3[:,0:3]
print(6)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
fil.reshape(-1)
# Out:
# array([0, 0, 0, ..., 2, 1, 0])

# %%
np.save('/data/dell5/userdir/heyi/data_cic/MR7fil_500_2.1smooth_0.4Rs_heyi5.14.npy',fil)

# %%
lmd=lmd.reshape(N,N,N,3)

# %%
v=np.zeros([500,500,500,3,3])
v[0:500,0:500,0:500,0,0:3]=n1.reshape(500,500,500,3)
v[0:500,0:500,0:500,1,0:3]=n2.reshape(500,500,500,3)
v[0:500,0:500,0:500,2,0:3]=n3.reshape(500,500,500,3)

# %%
np.save('/data/dell5/userdir/heyi/data_cic/MR7w_500_2.1smooth_0.4Rs_heyi5.14.npy',lmd)
np.save('/data/dell5/userdir/heyi/data_cic/MR7v_500_2.1smooth_0.4Rs_heyi5.14.npy',v)

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
N=500
fil=np.load('/data/dell5/userdir/heyi/data_cic/MR7fil_500_2.1smooth_0.4Rs_heyi5.14.npy')
fil=fil.reshape(N,N,N)
# %matplotlib inline
fig, ax = plt.subplots(figsize=(6,6))
a=fil[40:45,:,:]
#a=fil[:,60:64,:]
#a=fil[:,:,310:314]
b=np.max(a,axis=0)
#x=a.mean(axis=0)
#plt.imshow(x)

plt.imshow(b)
plt.colorbar()

#plt.gca().invert_yaxis()
#plt.imshow(x,cmap='Greys')


font1 = {'family' : 'Times New Roman',

'weight' : 'normal',

'size'   : 14,

}
font2 = {'family' : 'Times New Roman',

'weight' : 'normal',

'size'   : 13,

}
ax = plt.gca()    
ax.invert_yaxis()  
ax.tick_params(axis='both', which='major', labelsize=8)
 
plt.xlabel("X Mpc/h",font2)
plt.ylabel("Y Mpc/h",font2)
plt.show()
# Out:
# /home/guestupload/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# %store fil
# %store w
# %store v
# Out:
# Stored 'fil' (ndarray)
# UsageError: Unknown variable 'w'

# %%
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter
nd=np.load("/data/dell5/userdir/heyi/data_cic/densitymulone.npy")
n=500
ave=np.sum(nd)/n/n/n
nd[np.where(nd==0)]=ave
#高斯滤波
nd=(nd-ave)/ave
nd=gaussian_filter(nd, sigma=2.1)
x1=nd[40:45,:,:]#/meanpho-1

x1=x1.mean(axis=0)

fig, ax = plt.subplots(figsize=(6,6))
plt.imshow(np.log(x1))
#plt.colorbar()
# Out:
# /home/guestupload/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in log
#   from ipykernel import kernelapp as app

# %%
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter
import numpy as np
# %matplotlib inline
nd=np.load("/data/dell5/userdir/heyi/data_cic/densitymulthree_gu.npy")
n=500
ave=np.sum(nd)/n/n/n
nd[np.where(nd==0)]=ave
#高斯滤波
nd=(nd-ave)/ave
nd=gaussian_filter(nd, sigma=2.1)
x1=nd[40:45,:,:]#/meanpho-1

x1=x1.mean(axis=0)

fig, ax = plt.subplots(figsize=(6,6))
plt.imshow(np.log(x1))
#plt.colorbar()

font1 = {'family' : 'Times New Roman',

'weight' : 'normal',

'size'   : 14,

}
font2 = {'family' : 'Times New Roman',

'weight' : 'normal',

'size'   : 13,

}

ax.tick_params(axis='both', which='major', labelsize=8)

plt.xlabel("X Mpc/h",font2)
plt.ylabel("Y Mpc/h",font2)
ax = plt.gca()    
ax.invert_yaxis()
# Out:
# /home/guestupload/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in log
# /home/guestupload/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
c=fil
nn1=np.shape(np.where(c==0))
nn2=np.shape(np.where(c==1))
nn3=np.shape(np.where(c==2))
nn4=np.shape(np.where(c==3))
print(nn1[1]/N/N/N,nn2[1]/N/N/N,nn3[1]/N/N/N,nn4[1]/N/N/N)
# Out:
# 0.559339672 0.32274589600000003 0.109905304 0.008009128

# %%
N=500
fil=fil.reshape(N,N,N)
c=fil
voidpos=np.where(c==0)
sheetpos=np.where(c==1)
filpos=np.where(c==2)
clusterpos=np.where(c==3)
sumw=(lmd.sum(axis=3).reshape(-1))

# %%
nd=np.load("//data/dell5/userdir/heyi/data_cic/densitymulthree_gu.npy")

# %%
sumnd=nd.sum()
n1=nd[voidpos].sum()/sumnd
n2=nd[sheetpos].sum()/sumnd
n3=nd[filpos].sum()/sumnd
n4=nd[clusterpos].sum()/sumnd
print(n1,n2,n3,n4)
# Out:
# 0.19178626264515242 0.2866838945587655 0.3272866618945726 0.1942431809015151
